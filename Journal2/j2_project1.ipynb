# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def expFunc(a, b, x):
    return a*np.exp(-b*x)

# %%
x = np.linspace(0, 2 * np.pi, 100)
y = expFunc(1.25, 2.5, x)

# %%
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()
